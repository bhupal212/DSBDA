# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn .datasets import load_iris

# %%
x,y=load_iris(return_X_y=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
gn=GaussianNB()
gn
# Out:
# GaussianNB()

# %%
gn.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gn.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 1, 0, 1, 0, 2, 0, 1, 1, 2, 0, 1, 0, 1, 2, 1, 0, 2, 0, 0, 1,
#        2, 0, 2, 1, 1, 0, 0, 0])

# %%
pd.DataFrame(data={'actual':y_test,'predict':y_pred})
# Out:
#     actual  predict
# 0        1        1
# 1        0        0
# 2        1        1
# 3        0        0
# 4        1        1
# 5        0        0
# 6        2        2
# 7        0        0
# 8        1        1
# 9        1        1
# 10       2        2
# 11       0        0
# 12       1        1
# 13       0        0
# 14       1        1
# 15       2        2
# 16       1        1
# 17       0        0
# 18       2        2
# 19       0        0
# 20       0        0
# 21       1        1
# 22       2        2
# 23       0        0
# 24       2        2
# 25       2        1
# 26       1        1
# 27       0        0
# 28       0        0
# 29       0        0

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay,precision_score,recall_score

# %%
c=confusion_matrix(y_test,y_pred)

# %%
c
# Out:
# array([[13,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  1,  6]], dtype=int64)

# %%
c1=ConfusionMatrixDisplay(confusion_matrix=c)

# %%
c1.plot()

# %%
a=accuracy_score(y_test,y_pred)

# %%
e=1-a
e
# Out:
# 0.033333333333333326

# %%
tn,fp,fn=confusion_matrix(y_test,y_pred)

# %%
print(tn,fp,fn)
# Out:
# [13  0  0] [ 0 10  0] [0 1 6]

# %%
p=precision_score(y_test,y_pred,average="macro")

# %%
p
# Out:
# 0.9696969696969697

# %%
r=recall_score(y_test,y_pred,average="macro")

# %%
r
# Out:
# 0.9523809523809524
