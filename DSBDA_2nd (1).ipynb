# %%
import pandas as pd

# %%
df=pd.read_csv("student_data.csv")

# %%
df
# Out:
#    RollNo      Name  Age  Maths  Science  English  Total  Average
# 0     0 1     Anish   18   25.0       35       56  116.0      NaN
# 1     1 2  Aasawari   20   33.0       78       34  145.0     48.3
# 2     2 3    Aditya   11   90.0       33       22  145.0     48.3
# 3     3 4   Apoorva   22   45.0       88       56  189.0     63.0
# 4     4 5      Anil   12   66.0       43       88  197.0     65.7
# 5     5 6     Bablu   13    NaN       35       53  110.0      NaN
# 6     6 7    Chetan   12   56.0       66       78    NaN     66.7
# 7     7 8   Chinmay   14   56.0       36       68  160.0     53.3
# 8     8 9    Chitra   15   67.0       22       32  121.0     40.3
# 9    9 10      Diya   16   54.0       78       88  220.0     73.3
# 10  10 11    Deepak   34   33.0       44       71  148.0     49.3
# 11  11 12     Dilip   18   87.0       89       37  213.0      NaN
# 12  12 13      Esha   19   89.0       53       40  182.0     60.7
# ...

# %%
df.isnull().sum()
# Out:
# RollNo     0
# Name       0
# Age        0
# Maths      2
# Science    0
# English    0
# Total      2
# Average    3
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
newdf=df[df["Maths"] > 30]

# %%
newdf
# Out:
#    RollNo      Name  Age  Maths  Science  English  Total  Average
# 1     1 2  Aasawari   20   33.0       78       34  145.0     48.3
# 2     2 3    Aditya   11   90.0       33       22  145.0     48.3
# 3     3 4   Apoorva   22   45.0       88       56  189.0     63.0
# 4     4 5      Anil   12   66.0       43       88  197.0     65.7
# 6     6 7    Chetan   12   56.0       66       78    NaN     66.7
# 7     7 8   Chinmay   14   56.0       36       68  160.0     53.3
# 8     8 9    Chitra   15   67.0       22       32  121.0     40.3
# 9    9 10      Diya   16   54.0       78       88  220.0     73.3
# 10  10 11    Deepak   34   33.0       44       71  148.0     49.3
# 11  11 12     Dilip   18   87.0       89       37  213.0      NaN
# 12  12 13      Esha   19   89.0       53       40  182.0     60.7
# 13  13 14    Fatima   17   34.0       45       78  157.0     52.3
# 14  14 15      Faiz   11   32.0       51       27  110.0     36.7
# ...

# %%
newdf.boxplot
# Out:
# <bound method boxplot_frame of    RollNo      Name  Age  Maths  Science  English  Total  Average
# 1     1 2  Aasawari   20   33.0       78       34  145.0     48.3
# 2     2 3    Aditya   11   90.0       33       22  145.0     48.3
# 3     3 4   Apoorva   22   45.0       88       56  189.0     63.0
# 4     4 5      Anil   12   66.0       43       88  197.0     65.7
# 6     6 7    Chetan   12   56.0       66       78    NaN     66.7
# 7     7 8   Chinmay   14   56.0       36       68  160.0     53.3
# 8     8 9    Chitra   15   67.0       22       32  121.0     40.3
# 9    9 10      Diya   16   54.0       78       88  220.0     73.3
# 10  10 11    Deepak   34   33.0       44       71  148.0     49.3
# 11  11 12     Dilip   18   87.0       89       37  213.0      NaN
# 12  12 13      Esha   19   89.0       53       40  182.0     60.7
# 13  13 14    Fatima   17   34.0       45       78  157.0     52.3
# 14  14 15      Faiz   11   32.0       51       27  110.0     36.7
# ...

# %%
newdf.boxplot()
# Out:
# <Axes: >
